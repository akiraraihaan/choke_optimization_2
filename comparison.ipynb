# %% [markdown]
# ## result comparison so far
# ### (each best after 5 k-folds CV)
# 1. Gradient Boosting: F-14
# R2 -> 0.9857
# std dev -> 0.0037
#
# 2. Extra Trees Regressor: F-14
# R2 -> 0.9865
# std dev -> 0.0022
#
# 3. Ridge Regressor: F-14
# R2 -> 0.8276
# std dev -> 0.0532
#
# 4. Lasso Regressor: F-14
# R2 -> 0.8276
# std dev -> 0.0532
#
# 5. Random Forest Regressor: F-14
# R2 -> 0.9811
# std dev -> 0.0081

# %% [markdown]
# overall best
#
# > Extra Trees Regressor
#
# > Gradient Boosting Regressor
